# %%
def primeCheck(num):
      for i in range(2,num):
          if num % i == 0:
             return False
          else:
            return True 
 
ans=filter(primeCheck, range(2500))
print(list(ans))
